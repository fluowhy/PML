# %% [markdown]
# # Tarea 3

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.optimize import minimize
# %matplotlib inline 
plt.rcParams['figure.figsize'] = (10.0, 10.0)

# %%
def sigmoid(x):
    return 1/(1 + np.exp(-x))


def log_like(w, x, y): # - log likelihood
    # aumentar dimension para modelo lineal
    sig = sigmoid(x@w)
    return - np.sum(y*np.log(sig) + (1 - y)*np.log(1 - sig))


def prediccion(y_pred, y):
    """Retorna el total de la muestra, hits y % de precision"""
    total = len(y)
    hits = np.sum(y_pred==y)
    return total, hits, np.around(hits/total, 2)*100


def log_normal(mu, sigma, x):
    dim = len(mu)
    cen = x - mu
    return - 0.5*cen@np.linalg.inv(sigma)@cen.T - np.log((2*np.pi)**dim*np.linalg.det(sigma))
    
    
def met_has(w0, N, X, Y, prior=None, s1=1e-2):  # prior=None->Uniforme
                                                # prior=5->Gaussiana de cov diagonal 5 y mu=w0
    ndim = len(w0)
    p0 = - log_like(w0, X, Y) # "-" para obtener la log likelihood de vuelta
    if prior!=None:
        cov_prior = np.eye(ndim)*prior
        p0 += log_normal(mu=w0, sigma=cov_prior, x=w0)
    chain = []
    for i in range(N):
        w1 = np.random.multivariate_normal(w0, np.eye(ndim)*s1)
        p1 = - log_like(w1, X, Y)
        if prior!=None:
            p1 += log_normal(mu=w0, sigma=cov_prior, x=w1)
        un = np.log(np.random.uniform(0, 1))
        alpha = min(0, p1 - p0)
        if alpha>=un:
            chain.append(w1)
            p0 = p1
            w0 = w1
    print('acept', len(chain)/N)
    return np.array(chain)


def plt_bar(data, xlabel, bins=10):
    # data: n samples, d dimensions
    dim = data.shape[1]
    moda = []
    for i in range(dim):
        fig = plt.subplot(3, 1, i + 1)
        counts, limits = np.histogram(data.T[i], bins=bins)
        width = (limits[1] - limits[0])*0.9
        limits = (limits[1:] + limits[:-1])/2    
        print('moda '+xlabel[i], np.around(limits[np.argmax(counts)], 2))
        fig.bar(limits, counts, width=width, tick_label=np.around(limits, 2), color='navy')
        fig.set_ylabel('counts')
        fig.set_xlabel(xlabel[i])
        moda.append(limits[np.argmax(counts)])
    return moda

# %%
datos = np.genfromtxt('datosT3_.txt', dtype='float', delimiter=',')

# %%
clase_0 = datos[2]==0
clase_1 = datos[2]==1

# plot de datos
plt.scatter(datos[0][clase_0], datos[1][clase_0], marker='o', color='navy', label='clase 0', alpha=0.5)
plt.scatter(datos[0][clase_1], datos[1][clase_1], marker='o', color='red', label='clase 1', alpha=0.5)
plt.xlabel('x')
plt.ylabel('y')
plt.legend()

# %% [markdown]
# ## Regresión logística
#
# ### Modelo: $f(x, y) = w_{1}x + w_{2}y + w_{0}$

# %%
# solucion de la regresion logistica
X = datos[:2].T
Y = datos[2]
x0 = np.random.uniform(0, 1, 3)
if len(x0)==3:
    X = np.vstack((X.T, np.ones(len(X)))).T
w_opt = minimize(fun=log_like, x0=x0, args=(X, Y), method='L-BFGS-B').x
print('w =', w_opt)

# resultados de clasificacion
y_pred = sigmoid(X@w_opt)
y_pred[y_pred<0.5] = 0
y_pred[y_pred>=0.5] = 1

res = prediccion(y_pred, Y)
print('hits =', res[1], '/', res[0])
print('precision =', res[2], '%')
# Out:
# w = [ 2.2317689  -2.19648698  0.71665153]
# hits = 871 / 1000
# precision = 87.0 %

# %%
# plot recta separadora de clases

x = datos[0]
print(x.shape)
y_opt = (- w_opt[2] - w_opt[0]*x)/w_opt[1]

plt.plot(x, y_opt, color='black', label='separacion')
plt.scatter(datos[0][clase_0], datos[1][clase_0], marker='o', color='navy', label='clase 0', alpha=0.5)
plt.scatter(datos[0][clase_1], datos[1][clase_1], marker='o', color='red', label='clase 1', alpha=0.5)
plt.legend()
plt.title('datos reales')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# (1000,)
# Text(0,0.5,'y')

# %% [markdown]
# ## Metropolis Hastings

# %% [markdown]
# ### Prior uniforme

# %%
muestras_u = met_has(w_opt, 1000, X, Y, prior=None, s1=3.8*1e-2)
# Out:
# acept 0.23

# %%
fig1 = plt.subplot(2, 2, 1)
fig2 = plt.subplot(2, 2, 3)
fig3 = plt.subplot(2, 2, 4)
fig1.scatter(muestras_u.T[0], muestras_u.T[1], marker='o', alpha=0.5)
fig2.scatter(muestras_u.T[0], muestras_u.T[2], marker='o', alpha=0.5)
fig3.scatter(muestras_u.T[1], muestras_u.T[2], marker='o', alpha=0.5)

fig1.set_ylabel(r'$w_{2}$')
fig2.set_xlabel(r'$w_{1}$')
fig2.set_ylabel(r'$w_{0}$')
fig3.set_xlabel(r'$w_{2}$')
fig1.set_title('Prior uniforme')
# Out:
# Text(0.5,1,'Prior uniforme')

# %% [markdown]
# ### Histogramas

# %%
moda_u = plt_bar(muestras_u, [r'$w_{1}$', r'$w_{2}$', r'$w_{0}$'], 10)
# Out:
# moda $w_{1}$ 2.2
# moda $w_{2}$ -2.19
# moda $w_{0}$ 0.66

# %% [markdown]
# ### Algunas rectas

# %%
mu_copy = np.copy(muestras_u)
np.random.shuffle(mu_copy) # se seleccionan las rectas de manera aleatoria
for i in mu_copy[:30]: # se grafican 100 rectas
    y = (- i[2] - i[0]*x)/i[1]
    plt.plot(x, y, color='red', alpha=0.1)
plt.plot(x, y_opt, color='black', alpha=0.7, label='regresion')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()

# %% [markdown]
# ### Prior gaussiano
# $\Sigma = \text{diag}(1)$

# %%
muestras_n1 = met_has(w_opt, 1000, X, Y, prior=1, s1=3.8*1e-2)
# Out:
# acept 0.238

# %%
fig1 = plt.subplot(2, 2, 1)
fig2 = plt.subplot(2, 2, 3)
fig3 = plt.subplot(2, 2, 4)
fig1.scatter(muestras_n1.T[0], muestras_n1.T[1], marker='o', alpha=0.5)
fig2.scatter(muestras_n1.T[0], muestras_n1.T[2], marker='o', alpha=0.5)
fig3.scatter(muestras_n1.T[1], muestras_n1.T[2], marker='o', alpha=0.5)

fig1.set_ylabel(r'$w_{2}$')
fig2.set_xlabel(r'$w_{1}$')
fig2.set_ylabel(r'$w_{0}$')
fig3.set_xlabel(r'$w_{2}$')
fig1.set_title('Prior gaussiano')
# Out:
# Text(0.5,1,'Prior gaussiano')

# %% [markdown]
# ### Histogramas

# %%
moda_n1 = plt_bar(muestras_n1, [r'$w_{1}$', r'$w_{2}$', r'$w_{0}$'], 10)
# Out:
# moda $w_{1}$ 2.29
# moda $w_{2}$ -2.19
# moda $w_{0}$ 0.69

# %%
mn1_copy = np.copy(muestras_n1)
np.random.shuffle(mn1_copy)
for i in mn_copy[:30]:
    y = (- i[2] - i[0]*x)/i[1]
    plt.plot(x, y, color='red', alpha=0.1)
plt.plot(x, y_opt, color='black', alpha=0.7, label='regresion')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()

# %% [markdown]
# ### Prior Gaussiano
# $\Sigma = \text{diag}(10)$

# %%
muestras_n2 = met_has(w_opt, 1000, X, Y, prior=10, s1=3.8*1e-2)

fig1 = plt.subplot(2, 2, 1)
fig2 = plt.subplot(2, 2, 3)
fig3 = plt.subplot(2, 2, 4)
fig1.scatter(muestras_n2.T[0], muestras_n2.T[1], marker='o', alpha=0.5)
fig2.scatter(muestras_n2.T[0], muestras_n2.T[2], marker='o', alpha=0.5)
fig3.scatter(muestras_n2.T[1], muestras_n2.T[2], marker='o', alpha=0.5)

fig1.set_ylabel(r'$w_{2}$')
fig2.set_xlabel(r'$w_{1}$')
fig2.set_ylabel(r'$w_{0}$')
fig3.set_xlabel(r'$w_{2}$')
fig1.set_title('Prior gaussiano')
# Out:
# acept 0.254
# Text(0.5,1,'Prior gaussiano')

# %% [markdown]
# ### Histogramas

# %%
moda_n2 = plt_bar(muestras_n2, [r'$w_{1}$', r'$w_{2}$', r'$w_{0}$'], 10)
# Out:
# moda $w_{1}$ 2.25
# moda $w_{2}$ -2.16
# moda $w_{0}$ 0.63

# %%
mn2_copy = np.copy(muestras_n2)
np.random.shuffle(mn2_copy) # se seleccionan las rectas de manera aleatoria
for i in mu_copy[:30]: # se grafican 100 rectas
    y = (- i[2] - i[0]*x)/i[1]
    plt.plot(x, y, color='red', alpha=0.1)
plt.plot(x, y_opt, color='black', alpha=0.7, label='regresion')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()

# %% [markdown]
# ### Resumen Modas

# %%
lab = ['uniforme', 'normal cov=1', 'normal cov=10']
params = [r'$w_{1}$', r'$w_{2}$', r'$w_{0}$']
modas = [moda_u, moda_n1, moda_n2]
for i in range(3): # recorre parametros
    fig = plt.subplot(1, 3, i + 1)
    for j in range(3): # recorres priors
        fig.scatter(0, modas[j][i], label=lab[j])
    fig.scatter(0, w_opt[i], marker='x', label='MAP')
    fig.set_title(params[i])   
    fig.legend()
